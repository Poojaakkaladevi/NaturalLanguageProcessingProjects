# %% [markdown]
# # **TopicModelling Medium Headlines**

# %% [markdown]
# # **Data: Medium Articles**

# %%
# check if we are using google colab
from pathlib import Path
import textwrap
if 'google.colab' in str(get_ipython()):
    from google.colab import drive
    drive.mount("/content/drive")
    # !pip install datasets transformers bertopic umap hdbscan  openai -U -qq

    base_folder = Path("/content/drive/MyDrive/Pooja_HP_Singh_Projects/NLP/HW8")
# Out:
# Mounted at /content/drive
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 90.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 18.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 98.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.9/221.9 kB 27.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 13.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 13.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 8.1 MB/s eta 0:00:00
#   Building wheel for umap (setup.py) ... done
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Building wheel for sentence-transformers (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.

# %%
data_path = base_folder/'titles_cleaned.csv'
model_folder = base_folder/'Models'
model_folder.mkdir(exist_ok=True, parents=True)

# %% [markdown]
# # **Task1: Data Preparation:**

# %%
import torch
from datasets import load_dataset, Dataset, load_from_disk
import pandas as pd

torch.cuda.is_available()
# Out:
# True

# %%
df = pd.read_csv(data_path)
dataset = Dataset.from_pandas(df)
# Save the dataset
dataset.save_to_disk(base_folder/'medium_titles')
# Load the dataset
dataset = load_from_disk(base_folder/'medium_titles')
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/28383 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# Dataset({
#     features: ['Unnamed: 0', 'url', 'title', 'claps', 'responses', 'readTime', '$oid', '$date', 'datetime', 'year', 'month', 'date', 'hour', 'minute', 'second'],
#     num_rows: 28383
# })

# %%
dataset.features
# Out:
# {'Unnamed: 0': Value(dtype='int64', id=None),
#  'url': Value(dtype='string', id=None),
#  'title': Value(dtype='string', id=None),
#  'claps': Value(dtype='float64', id=None),
#  'responses': Value(dtype='float64', id=None),
#  'readTime': Value(dtype='string', id=None),
#  '$oid': Value(dtype='string', id=None),
#  '$date': Value(dtype='string', id=None),
#  'datetime': Value(dtype='string', id=None),
#  'year': Value(dtype='float64', id=None),
#  'month': Value(dtype='float64', id=None),
#  'date': Value(dtype='float64', id=None),
#  'hour': Value(dtype='float64', id=None),
#  'minute': Value(dtype='float64', id=None),
#  'second': Value(dtype='float64', id=None)}

# %% [markdown]
# # **Extract Meta data**

# %%
titles = dataset["title"]

# %% [markdown]
# # **Get Sentence Embeddings and Save them on the disk**

# %%
from sentence_transformers import SentenceTransformer
import joblib

# # We load our model
embedding_model = SentenceTransformer('all-mpnet-base-v2')

# # The titles are converted to vector representations
# embeddings = embedding_model.encode(titles)
# joblib.dump(embeddings,model_folder/'medium_nlp_title_embeddings')

embeddings_medium_titles = joblib.load(model_folder/'medium_nlp_title_embeddings')

embeddings_medium_titles.shape
# Out:
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# (28383, 768)

# %% [markdown]
# # **Topic Modeling**

# %% [markdown]
# # **Task2: Initial BERTopic Analysis**
#
# - **Use SentenceBERT for creating embeddings. Save these embeddings for subsequent analysis**
# - **Use UMAP for dimensionality reduction**
# - **Use HDBSCAN for clustering**
# - **Initially employ c-TF-IDF to understand topic representation**

# %%
# Default pipeline can be implemented in three lines of code
from umap import UMAP
from hdbscan import HDBSCAN
from bertopic import BERTopic
topic_model = BERTopic()

# %%
# Improvement1 : we already have saved  embeddings, so we can use them to speed up the process

# improvement 2: add random_state to make the results reproducible
umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine', random_state=42)

# improvement 3: add min_cluster_size to remove small topics
# we earlier used 15, let us try 40
hdbscan_model = HDBSCAN(min_cluster_size=40, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

# improvement 4: Enhance topic representation by removing stopwords, infrequent words, and using bigrams
from sklearn.feature_extraction.text import CountVectorizer
vectorizer_model = CountVectorizer(stop_words="english", min_df=2, ngram_range=(1, 2))

# %%
# Creating the BERTopic model with embedding model

# topic_model = BERTopic(embedding_model=embedding_model, umap_model=umap_model, hdbscan_model=hdbscan_model, vectorizer_model=vectorizer_model)
# topics, probs = topic_model.fit_transform(documents=abstracts)

# Creating the BERTopic model without embedding model
topic_model = BERTopic(embedding_model=embedding_model, umap_model=umap_model,
                       hdbscan_model=hdbscan_model, vectorizer_model=vectorizer_model,
                       calculate_probabilities=True)
topics, probs = topic_model.fit_transform(embeddings=embeddings_medium_titles, documents=titles)

# %% [markdown]
# - **Analyze the generated topics for coherence and relevance**

# %%
topic_model.get_topic_info().head(20)
# Out:
#     Topic  Count                                               Name  \
# 0      -1  10741                            -1_medium_data_using_ai
# 1       0    621               0_design_ux_collective_ux collective
# 2       1    577                 1_seo_search_website_search engine
# 3       2    418            2_startup_founders_venture_entrepreneur
# 4       3    412       3_instagram_followers_reels_medium instagram
# 5       4    381              4_medium_insights medium_jessica_blue
# 6       5    379       5_data_data engineering_data science_science
# 7       6    364                6_linkedin_profile_leads_recruiters
# 8       7    340           7_brand_branding_identity_brand identity
# 9       8    337                    8_b2b_sales_marketing_b2b sales
# 10      9    335  9_chatgpt_use chatgpt_using chatgpt_medium cha...
# 11     10    321         10_email_email marketing_emails_email list
# 12     11    297                   11_google ads_ads_google_adwords
# 13     12    276  12_product_product manager_product management_...
# 14     13    273       13_social media_social_media_media marketing
# 15     14    267                   14_men_women_relationship_dating
# 16     15    257                    15_writing_write_writer_writers
# 17     16    250  16_digital marketing_digital_marketing_medium ...
# 18     17    242  17_copywriting_copywriter_copy_copywriter hand...
# 19     18    236    18_midjourney_midjourney prompts_prompts_images
#
#                                        Representation  \
# 0   [medium, data, using, ai, life, make, learning...
# 1   [design, ux, collective, ux collective, ui, de...
# 2   [seo, search, website, search engine, engine, ...
# 3   [startup, founders, venture, entrepreneur, sta...
# 4   [instagram, followers, reels, medium instagram...
# 5   [medium, insights medium, jessica, blue, holid...
# 6   [data, data engineering, data science, science...
# 7   [linkedin, profile, leads, recruiters, using l...
# 8   [brand, branding, identity, brand identity, lo...
# 9   [b2b, sales, marketing, b2b sales, b2b marketi...
# 10  [chatgpt, use chatgpt, using chatgpt, medium c...
# 11  [email, email marketing, emails, email list, l...
# 12  [google ads, ads, google, adwords, google adwo...
# 13  [product, product manager, product management,...
# 14  [social media, social, media, media marketing,...
# 15  [men, women, relationship, dating, trans, woma...
# 16  [writing, write, writer, writers, writing tips...
# 17  [digital marketing, digital, marketing, medium...
# 18  [copywriting, copywriter, copy, copywriter han...
# 19  [midjourney, midjourney prompts, prompts, imag...
#
#                                   Representative_Docs
# 0   [Understanding Self-Organising Map Neural Netw...
# 1   [Why so many Garamonds? - UX Collective, What ...
# 2   [SEO Guide: To Show You Path for SEO - Chandni...
# 3   [Is Your Startup a Good Fit for Venture Capita...
# 4   [How To Make The Best Out Of Your Time On Inst...
# 5   [If You Try To Do Everything, You Won’t Do Any...
# 6   [From Data Engineering to Prompt Engineering -...
# 7   [5 Tools for LinkedIn Marketing - Sangita Cham...
# 8   [The Social Brand, Brand, Branding and Brand I...
# 9   [UX Design  for the B2B Sales Funnel, The B2B ...
# 10  [ChatGPT 與資料視覺化 - twdsmeetup - Medium, Could C...
# 11  [GetResponse : Email Marketing — My Experience...
# 12  [Google Ads, Worth It Or Nah? - Sabinah Thagan...
# 13  [You are not a Product Manager, The Five Whys ...
# 14  [5 Social Media Marketing Strategies: The Ulti...
# 15  [The Real Reason Why Men Never Will Understand...
# 16  [The Secret to Writing Well, The Art of Timele...
# 17  [What is Digital Marketing? - Mohsin Javed - M...
# 18  [The Best Copywriting Advice From the Best Cop...
# 19  [The Ultimate Guide to MidJourney V5.1 (with i...

# %%
topic_model.get_topic(0)
# Out:
# [('ux', 0.06592439145786302),
#  ('design', 0.06549051932629224),
#  ('collective', 0.040765707518791376),
#  ('ux collective', 0.04035778648216826),
#  ('ui', 0.033589478862998776),
#  ('designer', 0.025541471422365476),
#  ('ux design', 0.025460751456712474),
#  ('designers', 0.02397647160984639),
#  ('ui ux', 0.020800567975427755),
#  ('case study', 0.02054463265617737)]

# %% [markdown]
# **Find Topics related to a keyword**

# %%
import numpy as np
embedding_model = SentenceTransformer('all-mpnet-base-v2')
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

def find_similar_topics(embedding_model, topic_model, search_term, top_n=5):
    # Get sorted list of topic IDs from BERTopic model
    topic_list = list(topic_model.topic_representations_.keys())
    topic_list.sort()

    # Generate search term embedding
    search_term_embedding = embedding_model.encode([search_term]).flatten()

    # Compute cosine similarity
    similarities = cosine_similarity(search_term_embedding.reshape(1, -1), topic_model.topic_embeddings_).flatten()

    # Find top n similar topics
    top_indices = np.argsort(similarities)[-top_n:][::-1]
    similar_topics = [topic_list[i] for i in top_indices]
    similarity_scores = [similarities[i] for i in top_indices]


    return similar_topics, similarity_scores

# %%
# Usage
similar_topics, similarity_scores = find_similar_topics(embedding_model, topic_model, "artificial intelligence", top_n=5)
similar_topics, similarity_scores
# Out:
# ([90, 78, 83, 98, 128],
#  [0.63014567, 0.6127476, 0.55421734, 0.5410559, 0.5394019])

# %%
print(topic_model.get_topic(90))
print("\n Representative docs of this cluster or topic are :{}".format(topic_model.get_representative_docs(90)))
# Out:
# [('ai', 0.07927404546479011), ('intelligence', 0.07351708080175273), ('artificial', 0.05055009913600644), ('artificial intelligence', 0.05022671053396143), ('replaced', 0.049804916122579035), ('replaced ai', 0.04382326386691487), ('ai changing', 0.04382326386691487), ('work', 0.03977152123819041), ('human', 0.03570632718366472), ('crisis', 0.032743371850298464)]
#
#  Representative docs of this cluster or topic are :['AI Is Changing What Intelligence Means: Here’s How To Become Valuable', 'AI Is Changing What Intelligence Means: Here’s How To Become Valuable', 'AI Is Changing What Intelligence Means: Here’s How To Become Valuable']

# %%
topic_model.get_topic(78)
# Out:
# [('ai tools', 0.15487077505129165),
#  ('tools', 0.11114731094627596),
#  ('ai', 0.07058373287999906),
#  ('free ai', 0.06435581643157848),
#  ('productivity', 0.03936979969289151),
#  ('best ai', 0.032158154168304975),
#  ('free', 0.02867736591257012),
#  ('artificial', 0.02689538964889113),
#  ('tools try', 0.024107035086339542),
#  ('try ai', 0.024107035086339542)]

# %%
topic_model.get_representative_docs(78)
# Out:
# ['5 Free AI Tools that You Must Try',
#  '5 AI Tools That Will Supercharge Your Productivity',
#  'Get More Done in Less Time with These 16 Free AI Tools']

# %%
topic_model.get_topic(83)
# Out:
# [('generative ai', 0.24844392421628927),
#  ('generative', 0.24017081059765574),
#  ('medium generative', 0.08588469916426494),
#  ('ai', 0.07439676259413729),
#  ('ai generative', 0.06551033356676622),
#  ('ai change', 0.03184642446966135),
#  ('landscape', 0.029085244036260807),
#  ('future', 0.025122344345165915),
#  ('change 2023', 0.024804346018589038),
#  ('like midjourney', 0.024804346018589038)]

# %%
topic_model.get_representative_docs(83)
# Out:
# ['Where are the opportunities for new startups in generative AI?',
#  'A Beginner’s Guide to Deciphering Generative AI',
#  'Generative AI: Time for Scrutiny']

# %%
topic_model.get_topic(98)
# Out:
# [('ai', 0.059385404900552254),
#  ('ai marketing', 0.05920989785186091),
#  ('marketing', 0.03678521619365308),
#  ('ai tools', 0.0320377925680739),
#  ('tools', 0.03050969179698731),
#  ('marketing tools', 0.025932903056287707),
#  ('generic', 0.025375670507940394),
#  ('transforming', 0.024719472521358317),
#  ('intelligence', 0.023007856620342753),
#  ('era', 0.022840327929054105)]

# %%
topic_model.get_representative_docs(98)
# Out:
# ['How to Stand Out as a Marketer in the Era of Generic AI Marketing?',
#  'How to Stand Out as a Marketer in the Era of Generic AI Marketing?',
#  'How to Stand Out as a Marketer in the Era of Generic AI Marketing?']

# %%
topic_model.get_topic(128)
# Out:
# [('ai ux', 0.07392206845247519),
#  ('designers', 0.07041465895312615),
#  ('ai design', 0.06466564718064363),
#  ('ux', 0.059656881330170705),
#  ('design', 0.057542244600205),
#  ('ai', 0.05469507101800757),
#  ('10 ai', 0.0536385941552412),
#  ('ux design', 0.04971193137230897),
#  ('opportunities challenges', 0.04796785096467664),
#  ('design opportunities', 0.04796785096467664)]

# %%
topic_model.get_representative_docs(128)
# Out:
# ['The Impact of AI on UX Design: Opportunities and Challenges',
#  'The Impact of AI on UX Design: Opportunities and Challenges',
#  'The Impact of AI on UX Design: Opportunities and Challenges']

# %% [markdown]
# - **Apply Hierarchical Clustering to find subgroups within the topics**

# %%
from scipy.cluster import hierarchy as sch

# Hierarchical topics
# linkage_function = lambda x: sch.linkage(x, 'single', optimal_ordering=True)
# hierarchical_topics = topic_model.hierarchical_topics(docs, linkage_function=linkage_function)

hierarchical_topics = topic_model.hierarchical_topics(titles)
topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# 100%|██████████| 131/131 [00:02<00:00, 60.01it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d6aceb1d-9222-4ce0-a8bf-4aada8096cc3" class="plotly-graph-div" style="height:2180px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6aceb1d-9222-4ce0-a8bf-4aada8096cc3")) {                    Plotly.newPlot(                        "d6aceb1d-9222-4ce0-a8bf-4aada8096cc3",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["diffusion_stable diffusion_stable_medium stable_diffusion models","","","diffusion_stable diffusion_stable_using stable_image generation"],"x":[0.0,0.2269247399167632,0.2269247399167632,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["openai_openai gpt_openai api_api_gpt api","","","gpt_tuning gpt_medium gpt_fine_tuning"],"x":[0.0,0.8188000752937823,0.8188000752937823,0.0],"xaxis":"x","y":[-35.0,-35.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["chatbot_bot_build_gpt_build custom","","","gpt_openai_openai gpt_openai api_api"],"x":[0.0,0.8344189615189072,0.8344189615189072,0.8188000752937823],"xaxis":"x","y":[-25.0,-25.0,-40.0,-40.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["llm_llms_llama_fine_tuning","","","language_language models_large language_large_models"],"x":[0.0,0.8370332130033431,0.8370332130033431,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","text":["gpt_chatbot_openai_bot_api","","","language_language models_large language_large_llm"],"x":[0.8344189615189072,1.0359000161911351,1.0359000161911351,0.8370332130033431],"xaxis":"x","y":[-32.5,-32.5,-60.0,-60.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","text":["python_python libraries_code_python tricks_libraries","","","image_opencv_image processing_python_processing"],"x":[0.0,0.8204622927740912,0.8204622927740912,0.0],"xaxis":"x","y":[-95.0,-95.0,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","text":["pdfs_extracting_invoice_pdf_text images","","","python_image_opencv_image processing_processing"],"x":[0.0,0.8459869124108111,0.8459869124108111,0.8204622927740912],"xaxis":"x","y":[-85.0,-85.0,-100.0,-100.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","text":["nlp_bert_spacy_similarity_language processing","","","python_image_opencv_image processing_processing"],"x":[0.0,0.9154654650630454,0.9154654650630454,0.8459869124108111],"xaxis":"x","y":[-75.0,-75.0,-92.5,-92.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","text":["machine learning_machine_learning_optimization_monte","","","trading_python_stock_pricing_trading bot"],"x":[0.0,0.8341696807528534,0.8341696807528534,0.0],"xaxis":"x","y":[-125.0,-125.0,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","text":["forecasting_time series_series_time_forecast","","","machine learning_trading_machine_learning_python"],"x":[0.0,0.9290170691870718,0.9290170691870718,0.8341696807528534],"xaxis":"x","y":[-115.0,-115.0,-130.0,-130.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","text":["sentiment_sentiment analysis_analysis_reviews_medium sentiment","","","customer_segmentation_churn_retention_rfm"],"x":[0.0,0.8796341750234654,0.8796341750234654,0.0],"xaxis":"x","y":[-155.0,-155.0,-165.0 ...

# %% [markdown]
# - **Examine the clusters and subclusters, providing a comprehensive conclusion of the findings**

# %% [markdown]
# **Conclusion:**
#
# To sum it all up, for example, the groups labeled 89, 127, and 32 are all about big data tech – they kind of stick together in a neat bundle. On the flip side, clusters 103, 11, and 74 are like a team, especially with subgroups focusing on Google Ads and Facebook Ads. It's pretty obvious they're all into the advertising scene. Simply put, using BERTopic Analysis to figure things out showed that Medium articles are nicely sorted out by common topics in these clusters and subclusters.

# %%
# Save original representations
from copy import deepcopy
original_topics = deepcopy(topic_model.topic_representations_)

# %%
def compare_topic_changes(new_model, original_topic_words, max_length=75, top_n_topics=10):

    """Displays differences in top words of topic representations between the original and new models."""

    for topic_id in range(top_n_topics):
        # Extract top 5 words per topic from the original and new models
        original_top_words = "_".join(word for word, _ in original_topic_words[topic_id][:5])
        new_top_words = "_".join(word for word, _ in new_model.get_topic(topic_id)[:5])

        # Calculate whitespace for alignment
        alignment_spaces = " " * (max_length - len(original_top_words))

        # Print 'before' and 'after' topic word changes
        print(f"Topic: {topic_id}    {original_top_words}{alignment_spaces} >>     {new_top_words}")

# %% [markdown]
# # **Task3: KeyBERTInspired**
# - **Update the topic representation using the KeyBERTinspired approach**

# %%
# KeyBERTInspired
from bertopic.representation import KeyBERTInspired
representation_model = KeyBERTInspired()

# Update our topic representations
topic_model.update_topics(titles, representation_model=representation_model)

# %% [markdown]
# - **Compare the topic representation frkim step1 with the KeyBERTinspired approach**

# %%
# Show topic differences
compare_topic_changes(topic_model, original_topics)
# Out:
# Topic: 0    design_ux_collective_ux collective_ui                                       >>     designs_design_designing_ux_designers
# Topic: 1    seo_search_website_search engine_engine                                     >>     seo_marketing_indexing_keywords_google
# Topic: 2    startup_founders_venture_entrepreneur_startups                              >>     startups_startup_investors_founders_entrepreneurship
# Topic: 3    instagram_followers_reels_medium instagram_instagram followers              >>     instagram_insta_ig_marketing_media
# Topic: 4    medium_insights medium_jessica_blue_holiday medium                          >>     song_jessica_music_wildfire_medium
# Topic: 5    data_data engineering_data science_science_data analyst                     >>     data_analyst_analytics_analytical_study
# Topic: 6    linkedin_profile_leads_recruiters_using linkedin                            >>     linkedin_recruiters_jobs_marketing_freelance
# Topic: 7    brand_branding_identity_brand identity_logo                                 >>     branding_rebranding_brands_rebrands_marketing
# Topic: 8    b2b_sales_marketing_b2b sales_b2b marketing                                 >>     sales_b2b_marketing_b2c_salespeople
# Topic: 9    chatgpt_use chatgpt_using chatgpt_medium chatgpt_use                        >>     chatgpt_chat_gpt_ui_plugins

# %%
topic_model.get_topic(0, full=True)
# Out:
# {'Main': [('designs', 0.5236881),
#   ('design', 0.5090069),
#   ('designing', 0.49625993),
#   ('ux', 0.4818933),
#   ('designers', 0.47707564),
#   ('ui', 0.44034895),
#   ('trends', 0.4198845),
#   ('innovation', 0.399446),
#   ('industry', 0.37858674),
#   ('usability', 0.36983)]}

# %% [markdown]
# - **Reapply Hierarchical Clustering to discover subgroups under this new representation**

# %%
hierarchical_topics = topic_model.hierarchical_topics(titles)
topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# 100%|██████████| 132/132 [00:20<00:00,  6.59it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="89bf4368-e100-49d9-a550-5206dd5179ef" class="plotly-graph-div" style="height:2195px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89bf4368-e100-49d9-a550-5206dd5179ef")) {                    Plotly.newPlot(                        "89bf4368-e100-49d9-a550-5206dd5179ef",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["income_earning_earn_passive_passively","","","moneypreneur_selling_5000_wealth_earnt"],"x":[0.0,0.820996141762058,0.820996141762058,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["affiliate_affiliates_marketing_marketers_resell","","","income_earn_earnings_passive_passively"],"x":[0.0,0.9144862046155217,0.9144862046155217,0.820996141762058],"xaxis":"x","y":[-15.0,-15.0,-30.0,-30.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["affiliate_affiliates_marketing_marketers_income","","","youtube_monetize_monetised_channels_videos"],"x":[0.9144862046155217,0.9380352294139261,0.9380352294139261,0.0],"xaxis":"x","y":[-22.5,-22.5,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["etsy_print_printables_printable_canvases","","","affiliate_affiliates_marketing_marketers_marketer"],"x":[0.0,0.9630656830921741,0.9630656830921741,0.9380352294139261],"xaxis":"x","y":[-5.0,-5.0,-33.75,-33.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["freelance_articles_publications_sites_websites","","","earning_moneypreneur_earn_websites_jobs"],"x":[0.0,0.5736827799705597,0.5736827799705597,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["earning_websites_earn_moneypreneur_income","","","ai_earn_businesses_income_automation"],"x":[0.5736827799705597,0.695520730297957,0.695520730297957,0.0],"xaxis":"x","y":[-60.0,-60.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["earning_earn_moneypreneur_jobs_income","","","hustles_hustle_income_profitable_earn"],"x":[0.695520730297957,0.809006125277054,0.809006125277054,0.0],"xaxis":"x","y":[-67.5,-67.5,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["affiliate_marketing_marketer_sales_youtube","","","moneypreneur_hustles_income_hustle_earning"],"x":[0.9630656830921741,0.9970861175348089,0.9970861175348089,0.809006125277054],"xaxis":"x","y":[-19.375,-19.375,-76.25,-76.25],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["chatgpt_chat_gpt_ui_plugins","","","chatgpt_monetize_earning_chat_traders"],"x":[0.0,0.4766749964556588,0.4766749964556588,0.0],"xaxis":"x","y":[-105.0,-105.0,-115.0,-115.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["chatgpt_prompts_prompt_prompting_commands","","","chatgpt_chat_gpt_discord_plugins"],"x":[0.0,0.642048695627775,0.642048695627775,0.4766749964556588],"xaxis":"x","y":[-95.0,-95.0,-110.0,-110.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["chatgpt_chat_prompts_gpt_prompt","","","chatgpt_chatbots_chatgtp_ai_deepmind"],"x":[0.642048695627775,0.6991695227729383,0.6991695227729383,0.0],"xaxis":"x","y":[-102.5,-102.5,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,20 ...

# %% [markdown]
# **Conclusion:**
#
# If we look at the hierarchial clustering from keyBert Inspired method.For example 102,9,79,108 are all related to ChatGpt and were clustered together. Another example 24,57 are related to crypto currency and are clustered togerther. One outlier I See is the chinese character in cluster 76 which isn't linked to other elements which are based on linkedin and internet. All the subcluster look accurate and hierarchial has done a good job of clustering like topics.

# %%
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic

# %%
# !jupyter nbconvert --to pdf /content/drive/MyDrive/Pooja_HP_Singh_Projects/NLP/HW8/Pooja_Akkaladevi_HW_8.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Pooja_HP_Singh_Projects/NLP/HW8/Pooja_Akkaladevi_HW_8.ipynb to pdf
# /usr/local/lib/python3.10/dist-packages/nbconvert/filters/datatypefilter.py:41: UserWarning: Your element with mimetype(s) dict_keys(['text/html']) is not able to be represented.
#   warn(
# /usr/local/lib/python3.10/dist-packages/nbconvert/filters/datatypefilter.py:41: UserWarning: Your element with mimetype(s) dict_keys(['text/html']) is not able to be represented.
#   warn(
# [NbConvertApp] Writing 89883 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 92944 bytes to /content/drive/MyDrive/Pooja_HP_Singh_Projects/NLP/HW8/Pooja_Akkaladevi_HW_8.pdf
